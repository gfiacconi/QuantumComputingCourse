# %% [markdown]
# # Quantum Computing Course  💻  🧬
# ## Introduction 📚
# ### What's the difference betewwen a *Classical computer* and a *Quantum computer*

# %% [markdown]
# #### Classical computer
# - is based on the voltage across the devices
# - classical bit has 2 value: **0** and **1**
#
# But we have a few **Problems**:
# >- The Moore's Law which said that the number of the chips inside a computer duplicate every 18 months which generate the
# >- Downscaling problme beacuse more we reduce the component-parts more some side-quantum-effects occur
#
# #### Quantum Computer
# - operate be using quantum phenomena like the **Superpositin** and the **Entaglement**
# - so it just use atomic properties and molecules
# - best of all it can compute parallel processing
#
# ##### Quantum Bit (Qubit)
# A Qubit is vector in a Complex Space based on two fondamentlas state:
# $$
# |0\rangle\
# |1\rangle\
# $$
#
# which is a **Orthonormal Bases** in the **Block Sphere**.
# The generic vector corrispond to:
#
# $$ |\psi\rangle =\alpha\|0\rangle+\beta|1\rangle\ $$
#
# Now we will skip the explenation of **wave particle duality**, the **Klein-Gordon** and the **Schörodinger Equation** and we assume to know them to jump directly to the core of the Quantum Computing
# ___

# %% [markdown]
# ## Block Sphere 🌏
# The fondamental unit for the quantum computer are the $|0\rangle\ |1\rangle\$
# Let's visualize them by using the **Block Sphere**

# %%
import math
from math import pi
from qiskit_textbook.widgets import plot_bloch_vector
zeroState = [0,0,1] # [X, Y, Z]
plot_bloch_vector(zeroState,title='Zero State',figsize=(4,4)) # Bloch Vector with spherical coordinates

# %%
import math
from math import pi
from qiskit_textbook.widgets import plot_bloch_vector
oneState = [0,0,-1] # [X, Y, Z]
plot_bloch_vector(oneState,title='One State',figsize=(4,4)) # Bloch Vector with spherical coordinates

# %% [markdown]
# The **Block Sphere** is a *vector space* constituted by the orthonormal base $|0\rangle\ |1\rangle\ $ with which we can construct the Superposition of the states by simply making a linear combination of them.
# The generic Qubit is rappresented by:
#
# $$|\psi\rangle =\alpha\|0\rangle+\beta|1\rangle\$$
# with $\vert\alpha\vert^2+\vert\beta\vert^2 = 0$
#
# Each *operation* with the Qubits corrispond to a ***Projection*** of $|\psi\rangle$ on the orthonormal base $|0\rangle\ |1\rangle\ $ and it **will not produce a be deterministic result** but a ***probabilistic*** result.
#
# >In fact $\vert\alpha\vert^2+\vert\beta\vert^2 = 0$ has a probabilistic meaning.
# >- $\vert\alpha\vert^2$ is the probability that $|\psi\rangle$ decay on $|0\rangle$
# >- $\vert\beta\vert^2$ is the probability that $|\psi\rangle$ decay on $|1\rangle$
#
# To describe a particular state of a particle we can introduce a complex vector space and associate at each state of the motion of the particle a vector in that space. This procedure was thought by professor *Werner Heisenberg* in his ***Matricial Formulation of the QUantum Mechanic in 1928**.
# So now in the complex vector space we can us all the properties of the complex vectors and we call it **H**.
#
# **H** now has all the significant wave functions and the identity function rapressented all by vectors.
# Those vectors are linearly indipendent.
# In general the Complex vector space can have two types of dimension
# - finite, and it correspond to the number of L.I. vectors
# - infinite
# in our case, **H** has all significant solutions of De Broglie wave functions.
#
# In quantum computing is common the BraKet notation or also called Dirac Notation
# 1. **Bra**
#     >- $\langle\ 0 \vert =\begin{bmatrix} 1 & 0 \end{bmatrix}$
#
#     >- $\langle\ 1 \vert = \begin{bmatrix} 0 & 1 \end{bmatrix}$
# 2. **Ket**
#     >- $|0\rangle =\begin{bmatrix} 1 \\ 0 \end{bmatrix}$
#
#    >- $|1\rangle = \begin{bmatrix} 0 \\ 1 \end{bmatrix}$
# ___
# Now let's introduce the operations.
# #### 1. Inner Product
# - the main result is to give a Scalar to a couple of vector
# let's see how it works:\
# \
# $\langle\ 0 \vert\ 1 \rangle = \begin{bmatrix} 1 & 0 \end{bmatrix} \begin{bmatrix} 1 \\ 0 \end{bmatrix} = (1 * 0)(0 * 1) = 0 $
# ___
# #### 2. Outer Product
# $|0\rangle\langle\ 1 \vert= |0\rangle\otimes\langle\ 1 \vert  = \begin{bmatrix} 1 \\ 0 \end{bmatrix} \otimes \begin{bmatrix} 0 & 1 \end{bmatrix} = \begin{bmatrix} 0 & 1 \\ 0 & 0 \end{bmatrix}$
# ___
# #### 3. Norms
# - is the distance from the origin
# $ \vert\vert\vert\ v\rangle \vert\vert = \sqrt{\langle\ v \vert\ v \rangle} $
# ___
# #### 4. Tensor product
# - it helps us to combine vector spaces in bigger vector spaces
# - it describes the interaction between 2quantum system\
# \
# $ |0\rangle\otimes\vert\ 1\rangle = |0\rangle\vert\ 1\rangle = |0 1\rangle = \begin{bmatrix} 1 \\ 0 \end{bmatrix}\begin{bmatrix} 0 \\ 1 \end{bmatrix} = \begin{bmatrix} 1*0 \\ 0*0 \end{bmatrix}= \begin{bmatrix} 0 \\ 0 \end{bmatrix} $
#
# ___
#
# We will use all of that properties to operate with quantum computers.
# In fact in the **Block Sphere** the quibit state is the result of linear combination of the vector bases and in a few word it is a geometric rappresentation of those states in the comlpex-vector-space of the qubits as point **in** the sphere, which is called *mixed-state*, and **on** the Surface, which is called *pure state*.
#
# #### Let's introduce some properties of the Block Sphere
#
# first of all a complex number is written like that:\
# $$ z = x + iy $$\
# \
# and by using **Polar coordinates** will be written as:\
# $$ z = r(\cos\theta + i\sin\theta) = re^{i\theta} $$
# \
# so we can re-write $|\psi\rangle$ as:\
# $$ |\psi\rangle = r_{\color{red}\alpha}e^{i\color{red}\phi}\vert 0\rangle+r_{\color{green}\beta}e^{i\color{green}\phi}\vert 1\rangle$$\
# \
# and by that we can notice and demostrate that **opposite points in the Block Sphere** *corrispond* to **Orthonormal State**.
# To see that we use Qiskit
# Qiskit [quiss-kit] is an open-source SDK for working with quantum computers at the level of pulses, circuits, and application modules.

# %%
import math
from math import pi
from qiskit_textbook.widgets import plot_bloch_vector
#plotting the ket-zero state
zeroState = [0,0,1] # [X, Y, Z]
plot_bloch_vector(zeroState,title='Ket-Zero State',figsize=(4,4)) # Bloch Vector with spherical coordinates

# %%
#plotting the ket-one state
oneState = [0,0,-1] # [X, Y, Z]
plot_bloch_vector(oneState,title='Ket-One State',figsize=(4,4)) # Bloch Vector with spherical coordinates

# %% [markdown]
#  *As you can notice* we said that the **orthonormal base** of our *quantum computer* is exactly $|0\rangle\ |1\rangle\$, which are the two states that we had just plotted,
#  ### **are opposite in our Block Sphere!**
#
#  Now let's mathematically demostrate it but without using formuls (just for now). The idea is the following:
#  - we start by putting $\psi$ in another way so that we can manipulate it
#  - then we change the angle from $\theta$ to $\theta/2$
#  - by doing that we notice that opposite points (we call it X-state) differ only by a phase factor of 1
#  - and at the end we have $\langle\ X\vert\psi\rangle=\cos(\pi/2)= 0$ **which is exactly the definition of orthonormal base**
# ___
# ## Remarkable Qubit-States
# | $\theta$ 	| $\phi$          	| $\psi$                                               	| Posizione        	|
# |----------	|-----------------	|------------------------------------------------------	|------------------	|
# | $0$      	| $-$             	| $\vert\ 0\rangle$                                    	| Polo Nord        	|
# | $\pi$    	| $-$             	| $\vert\ 1\rangle$                                    	| Polo Sud         	|
# | $\pi/2$  	| $0$             	| $\frac{\vert\ 0\rangle+ \vert\ 1\rangle}{\sqrt{2}}$  	| $\vert +\rangle$ 	|
# | $\pi/2$  	| $\pi$           	| $\frac{\vert\ 0\rangle- \vert\ 1\rangle}{\sqrt{2}}$  	| $\vert -\rangle$ 	|
# | $\pi/2$  	| $+\frac{\pi}{2}$ 	| $\frac{\vert\ 0\rangle+ i\vert\ 1\rangle}{\sqrt{2}}$ 	| $\vert R\rangle$ 	|
# | $\pi/2$  	| $-\frac{\pi}{2}$ 	| $\frac{\vert\ 0\rangle- i\vert\ 1\rangle}{\sqrt{2}}$ 	| $\vert L\rangle$ 	|
#
# with:

# %% [markdown]
# >$\vert 0\rangle = \begin{bmatrix} 1 \\ 0 \end{bmatrix} $;
#
# >$\vert 1\rangle = \begin{bmatrix} 0 \\ 1 \end{bmatrix} $;
#
# >$\vert +\rangle = \frac{1}{\sqrt{2}}\begin{bmatrix} 1 \\ 1 \end{bmatrix} $;
#
# >$\vert -\rangle = \frac{1}{\sqrt{2}}\begin{bmatrix} 1 \\ -1 \end{bmatrix} $;
#
# >$\vert R\rangle = \frac{1}{\sqrt{2}}\begin{bmatrix} 1 \\ i \end{bmatrix} $;
#
# >$\vert L\rangle = \frac{1}{\sqrt{2}}\begin{bmatrix} 1 \\ -i \end{bmatrix} $
#
# ### Let's Visualize them on The Block Sphere:

# %%
#plotting the ket-0 state
oneState = [0,0,1] # [X, Y, Z]
plot_bloch_vector(oneState,title='|0> State',figsize=(4,4)) # Bloch Vector with spherical coordinates

# %% [markdown]
# >$\vert 0\rangle = \begin{bmatrix} 1 \\ 0 \end{bmatrix} $;

# %%
#plotting the ket-1 state
oneState = [0,0,-1] # [X, Y, Z]
plot_bloch_vector(oneState,title='|1> State',figsize=(4,4)) # Bloch Vector with spherical coordinates

# %% [markdown]
# >$\vert 1\rangle = \begin{bmatrix} 0 \\ 1 \end{bmatrix} $;

# %%
#plotting the ket + state
oneState = [1,0,0] # [X, Y, Z]
plot_bloch_vector(oneState,title='|+> State',figsize=(4,4)) # Bloch Vector with spherical coordinates

# %% [markdown]
# >$\vert +\rangle = \frac{1}{\sqrt{2}}\begin{bmatrix} 1 \\ 1 \end{bmatrix} $;

# %%
#plotting the ket - state
oneState = [-1,0,0] # [X, Y, Z]
plot_bloch_vector(oneState,title='|-> State',figsize=(4,4)) # Bloch Vector with spherical coordinates

# %% [markdown]
# >$\vert -\rangle = \frac{1}{\sqrt{2}}\begin{bmatrix} 1 \\ -1 \end{bmatrix} $;

# %%
#plotting the ket-R state
oneState = [0,1,0] # [X, Y, Z]
plot_bloch_vector(oneState,title='|R> State',figsize=(4,4)) # Bloch Vector with spherical coordinates

# %% [markdown]
# >$\vert R\rangle = \frac{1}{\sqrt{2}}\begin{bmatrix} 1 \\ i \end{bmatrix} $;

# %%
#plotting the ket-L state
oneState = [0,-1,0] # [X, Y, Z]
plot_bloch_vector(oneState,title='|L> State',figsize=(4,4)) # Bloch Vector with spherical coordinates

# %% [markdown]
# >$\vert L\rangle = \frac{1}{\sqrt{2}}\begin{bmatrix} 1 \\ -i \end{bmatrix} $

# %% [markdown]
# ---

# %% [markdown]
# Now we will start to see the **Operators** and the **Quantum Logical Ports** by using those state that we have studied.
# ## Quantum Operators 🧮  and Quantum Logical Ports 🚪🧠
# ### Hadamard Port 🪙
# This port produce what is called **Superposition** state of the different state that we have in our register.
#
# **Superposition** means that we have the same **probability** for all of the states that we are watching, and that's why this port is called *Coin-Toss port*.
#
# Let's have an example:

# %%
from qiskit import QuantumCircuit, assemble, Aer #library to create quantum circuits
from math import pi, sqrt #usueful math tools
from qiskit.visualization import plot_bloch_multivector, plot_histogram #library to plor
sim = Aer.get_backend('aer_simulator')

qc1= QuantumCircuit(1) #we built a Single Qubit Gates set at |0> state

qc1.draw() #we draw it
# Out:
#
# q:

# %%
# Let's see |0> state where we set that we start:
qc1.save_statevector()
qobj = assemble(qc1)
state = sim.run(qobj).result().get_statevector()
plot_bloch_multivector(state)

# %%
#we applied an H-gate on our |0> qubit
qc2= QuantumCircuit(1)

qc2.h(0) 
qc2.draw()
# Out:
#    ┌───┐
# q: ┤ H ├
#    └───┘

# %%
# Let's see the result of an H-gate on our |0> qubit:
qc2.save_statevector()
qobj = assemble(qc2)
state = sim.run(qobj).result().get_statevector()
plot_bloch_multivector(state,title="H-gate on our |0> qubit")

# %% [markdown]
# We can notice that our vector set up at the $\vert 0\rangle$ state has moved...but why???🤨
#
# By appying the Hadamard port we rotated the vector.
#
# In fact the Hadamard port is an operator which is a function over a space of physical states onto another space of physical states...but we can say that is just a fuction that moves our vector in our space 🥲.
#
# If we do the math in fact we can see why we have this result.
#
# Let's start the dimostration by showing the **Hadamard-operator**:
# >$$ H = \frac{1}{\sqrt{2}}\begin{bmatrix} 1 & 1 \\ 1 & -1 \end{bmatrix} $$
#
# Which we can decompose in:
# > $$\frac{\vert\ 0\rangle+ i\vert\ 1\rangle}{\sqrt{2}} \langle 0\vert + \frac{\vert\ 0\rangle- i\vert\ 1\rangle}{\sqrt{2}} \langle 1\vert$$
#
#
# Now we apply it to the $\color{red}{\vert 0\rangle}$ that we set as our initial state:
# >$$ H\color{red}{\vert 0\rangle} = \frac{\vert\ 0\rangle+ i\vert\ 1\rangle}{\sqrt{2}} \langle 0\vert \color{red}{0 \rangle} + \frac{\vert\ 0\rangle- i\vert\ 1\rangle}{\sqrt{2}} \langle 1\vert\color{red}{ 0 \rangle} $$
#
# we can see that:
# $$\langle 0\vert0 \rangle=\begin{bmatrix} 1 & 0 \end{bmatrix}\begin{bmatrix} 1 \\ 0 \end{bmatrix} = (1*1) + (1*0) = 1$$
# and
# $$\langle 0\vert1 \rangle=\begin{bmatrix} 1 & 0 \end{bmatrix}\begin{bmatrix} 0 \\ 1 \end{bmatrix} = (1*0) + (0*1) = 0$$
#
# So we are left with just:
# >$$ H\vert 0\rangle = \frac{\vert\ 0\rangle+ i\vert\ 1\rangle}{\sqrt{2}} \langle 0\vert 0 \rangle $$
#
# which is just the  $\vert +\rangle$ state
#
# In fact if we bring it back we can see that is just the same:

# %%
#plotting the ket + state
oneState = [1,0,0] # [X, Y, Z]
plot_bloch_vector(oneState,title='|+> State',figsize=(4,4)) # Bloch Vector with spherical coordinates

# %% [markdown]
# so the **Hadamard Gate** produce a rotaion of $\frac{\pi}{2}$ along the Y-axis if applied to the initial state set up at $\vert\ 0\rangle$.
#
# But what will append if we applie it to an initial state set up at $\vert\ 1\rangle$???🧐
#
# Let's begin with just making our circuit.

# %%
qc3= QuantumCircuit(1) #we built a Single Qubit Gates set at |1> state
qc3.x(0) #i have applied an X-Pauli-Gate just to put it on |1>, we will see later what X-gate is...
qc3.draw() #we draw it
# Out:
#    ┌───┐
# q: ┤ X ├
#    └───┘

# %%
# Let's see the result of an H-gate on our |0> qubit:
qc3.save_statevector()
qobj = assemble(qc3)
state = sim.run(qobj).result().get_statevector()
plot_bloch_multivector(state,title="H-gate on our |1> qubit")

# %%
qc4= QuantumCircuit(1)
qc4.x(0)
#we applied the Hademard-Gate to the |1> initial state
qc4.h(0) 
#we start plotting
qc4.save_statevector()
qobj = assemble(qc4) 
state = sim.run(qobj).result().get_statevector()
plot_bloch_multivector(state,title="H-gate on our |1> qubit")

# %% [markdown]
# As you can see is the opposite of the $\vert 0\rangle$ so it corrispond to the $\vert -\rangle$ state.
#
# So the **Hadamard Gate** produce a rotaion of  $\frac{\pi}{2}$ along the X-axis if applied to the initial state set up at $\vert\ 1\rangle$.
